# %% [markdown]
# # Exploration de dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Training set on Breast cancer.csv')

# %%
df.shape
# Out:
# (569, 33)

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.drop('Unnamed: 32', axis = 1, inplace = True)

# %% [markdown]
# # Analyse de la forme des données

# %%
df.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.isna(), cbar=False)

# %%
(df.isna().sum()/df.shape[0]).sort_values(ascending=True)
# Out:
# id                         0.0
# concave points_worst       0.0
# concavity_worst            0.0
# compactness_worst          0.0
# smoothness_worst           0.0
# area_worst                 0.0
# perimeter_worst            0.0
# texture_worst              0.0
# radius_worst               0.0
# fractal_dimension_se       0.0
# symmetry_se                0.0
# concave points_se          0.0
# concavity_se               0.0
# compactness_se             0.0
# smoothness_se              0.0
# area_se                    0.0
# perimeter_se               0.0
# texture_se                 0.0
# radius_se                  0.0
# fractal_dimension_mean     0.0
# symmetry_mean              0.0
# concave points_mean        0.0
# concavity_mean             0.0
# compactness_mean           0.0
# smoothness_mean            0.0
# area_mean                  0.0
# perimeter_mean             0.0
# texture_mean               0.0
# radius_mean                0.0
# diagnosis                  0.0
# ...

# %% [markdown]
# # Examen de la colonne target

# %%
df['diagnosis'].value_counts(normalize=True)
# Out:
# B    0.627417
# M    0.372583
# Name: diagnosis, dtype: float64

# %%
df.select_dtypes('float').columns.value_counts(normalize=True)
# Out:
# radius_mean                0.033333
# concave points_se          0.033333
# symmetry_se                0.033333
# concavity_worst            0.033333
# concavity_mean             0.033333
# compactness_worst          0.033333
# texture_se                 0.033333
# compactness_se             0.033333
# radius_se                  0.033333
# area_mean                  0.033333
# smoothness_mean            0.033333
# smoothness_se              0.033333
# concavity_se               0.033333
# fractal_dimension_mean     0.033333
# compactness_mean           0.033333
# perimeter_worst            0.033333
# radius_worst               0.033333
# texture_mean               0.033333
# symmetry_mean              0.033333
# texture_worst              0.033333
# area_worst                 0.033333
# perimeter_se               0.033333
# concave points_mean        0.033333
# perimeter_mean             0.033333
# area_se                    0.033333
# symmetry_worst             0.033333
# ...

# %%
for col in df.select_dtypes('float'):
    plt.figure()
    sns.distplot(df[col])
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
df['diagnosis'].value_counts().plot.pie()

# %% [markdown]
# # Variables Qualitatives

# %%
df.corr()
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %%
pd.crosstab(df['diagnosis'], df['perimeter_worst'])
# Out:
# perimeter_worst  50.41   54.49   56.65   57.17   57.26   58.08   58.36   \
# diagnosis
# B                     1       1       1       1       1       1       1
# M                     0       0       0       0       0       0       0
#
# perimeter_worst  59.16   59.90   60.90   ...  202.40  205.70  206.00  206.80  \
# diagnosis                                ...
# B                     1       1       1  ...       0       0       0       0
# M                     0       0       0  ...       1       1       1       1
#
# perimeter_worst  211.50  211.70  214.00  220.80  229.30  251.20
# diagnosis
# B                     0       0       0       0       0       0
# M                     1       1       1       1       1       1
#
# [2 rows x 514 columns]

# %%
sns.countplot(x='fractal_dimension_mean', hue='diagnosis', data=df)

# %%
sns.countplot(x='texture_mean', hue='diagnosis', data=df)

# %%
sns.countplot(x='area_se', hue='diagnosis', data=df)

# %% [markdown]
# # Analyse un peu plus Avancée

# %%
for col in df.columns:
    plt.figure()
    sns.heatmap(pd.crosstab(df['diagnosis'], df[col]), annot=True, fmt='d')
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
sns.clustermap(df[df.columns].corr())

# %%
mean_col = ['diagnosis','radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']

sns.pairplot(df[mean_col],hue = 'diagnosis', palette='Accent')

# %%
df.corr()['radius_worst'].sort_values()
# Out:
# fractal_dimension_mean    -0.253691
# smoothness_se             -0.230691
# symmetry_se               -0.128121
# texture_se                -0.111690
# fractal_dimension_se      -0.037488
# id                         0.082405
# fractal_dimension_worst    0.093492
# symmetry_mean              0.185728
# concavity_se               0.186904
# compactness_se             0.204607
# smoothness_mean            0.213120
# smoothness_worst           0.216574
# symmetry_worst             0.243529
# texture_mean               0.352573
# concave points_se          0.358127
# texture_worst              0.359921
# compactness_worst          0.475820
# compactness_mean           0.535315
# concavity_worst            0.573975
# concavity_mean             0.688236
# perimeter_se               0.697201
# radius_se                  0.715065
# area_se                    0.757373
# concave points_worst       0.787424
# concave points_mean        0.830318
# area_mean                  0.962746
# ...

# %%
sns.violinplot(x="smoothness_mean",y="perimeter_mean",data=df)

# %% [markdown]
# # TrainTest - Nettoyage - Encodage

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999

# %%
from sklearn.model_selection import train_test_split

# %%
trainset, testset = train_test_split(df, test_size=0.2, random_state=0)

# %%
testset['diagnosis'].value_counts()
# Out:
# B    67
# M    47
# Name: diagnosis, dtype: int64

# %%
trainset['diagnosis'].value_counts()
# Out:
# B    290
# M    165
# Name: diagnosis, dtype: int64

# %%
def encodage(df):
    code = {'M':0,
            'B':1
           }
    
    for col in (df.select_dtypes('object').columns):
        df.loc[:,col] = df[col].map(code)
        
    return df

# %%
def imputation(df):
    #df = df.fillna(5)
    df = df.fillna(0, inplace=True)
    #df = df.dropna(axis=0)
    return  df

# %%
def preprocessing(df):
    
    df = encodage(df)
    imputation(df)
    drop_elements = ['diagnosis']
    X = df.drop(drop_elements, axis=1)
    y = df['diagnosis']
    
    print(y.value_counts())
    
    return X, y

# %%
X_train, y_train = preprocessing(trainset)
# Out:
# 1    290
# 0    165
# Name: diagnosis, dtype: int64

# %%
X_test, y_test = preprocessing(testset)
# Out:
# 1    67
# 0    47
# Name: diagnosis, dtype: int64

# %%
X_train.shape
# Out:
# (455, 31)

# %% [markdown]
# # Procédure d'évaluation

# %%
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.model_selection import learning_curve
from sklearn.metrics import recall_score

# %%
def evaluation(model):
    
    model.fit(X_train, y_train)
    ypred = model.predict(X_test)
    
    print(confusion_matrix(y_test, ypred))
    print(classification_report(y_test, ypred))
    #print(precision_score(y_test, ypred, average='micro'))
    scoring = ['f1_micro']
    for score in scoring:
        N, train_score, val_score = learning_curve(model, X_train, y_train, cv=4, scoring=score,train_sizes=np.linspace(0.1, 1, 10))
    
    plt.figure(figsize=(12, 8))
    plt.plot(N, train_score.mean(axis=1), label='train score')
    plt.plot(N, val_score.mean(axis=1), label='validation score')
    plt.legend()

# %% [markdown]
# # Modélisation

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

# %%
preprocessor = make_pipeline(PolynomialFeatures(2, include_bias=False), SelectKBest(f_classif, k=10))

# %%
RandomForest = make_pipeline(preprocessor, RandomForestClassifier(random_state=0))
AdaBoost = make_pipeline(preprocessor, AdaBoostClassifier(random_state=0))
SVM = make_pipeline(preprocessor, StandardScaler(), SVC(random_state=0))
KNN = make_pipeline(preprocessor, StandardScaler(), KNeighborsClassifier())

# %%
dict_of_models = {
                  'RandomForest': RandomForest,
                  'AdaBoost' : AdaBoost,
                  'SVM': SVM,
                  'KNN': KNN
                 }

# %%
for name, model in dict_of_models.items():
    print(name)
    evaluation(model)
# Out:
# RandomForest
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [[44  3]
#  [ 0 67]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        47
#            1       0.96      1.00      0.98        67
#
#     accuracy                           0.97       114
#    macro avg       0.98      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# AdaBoost
# [[44  3]
#  [ 0 67]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        47
#            1       0.96      1.00      0.98        67
#
#     accuracy                           0.97       114
#    macro avg       0.98      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# SVM
# ...

# %% [markdown]
# # OPTIMISATION

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
SVM
# Out:
# Pipeline(memory=None,
#          steps=[('pipeline',
#                  Pipeline(memory=None,
#                           steps=[('polynomialfeatures',
#                                   PolynomialFeatures(degree=2,
#                                                      include_bias=False,
#                                                      interaction_only=False,
#                                                      order='C')),
#                                  ('selectkbest',
#                                   SelectKBest(k=10,
#                                               score_func=<function f_classif at 0x0000026BD2799378>))],
#                           verbose=False)),
#                 ('standardscaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('svc',
#                  SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                      decision_function_shape='ovr', degree=3,
# ...

# %%
hyper_params = {'svc__gamma':[1e-3, 1e-4, 0.0005],
                'svc__C':[1, 10, 100, 1000, 3000], 
               'pipeline__polynomialfeatures__degree':[2, 3],
               'pipeline__selectkbest__k': range(45, 60)}

# %%
grid = RandomizedSearchCV(SVM, hyper_params, scoring='f1_micro', cv=4,
                          n_iter=40)

grid.fit(X_train, y_train)

print(grid.best_params_)

y_pred = grid.predict(X_test)
# Out:
# {'svc__gamma': 0.0001, 'svc__C': 3000, 'pipeline__selectkbest__k': 51, 'pipeline__polynomialfeatures__degree': 2}

# %%
evaluation(grid.best_estimator_)
# Out:
# [[46  1]
#  [ 1 66]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        47
#            1       0.99      0.99      0.99        67
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %% [markdown]
# # La régression logistique

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier=LogisticRegression(multi_class='multinomial', solver='lbfgs', penalty='l2', C=1.0)
classifier.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='multinomial', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#faire des nouvelles prédictions
y_pred=classifier.predict(X_test)
classifier.score(X_test,y_test)
# Out:
# 0.5877192982456141

# %%
# Matrice de confusion
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[ 0 47]
#  [ 0 67]]

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
print("Precision Score : ",precision_score(y_test, y_pred,  pos_label='positive',average='micro'))
print("Recall Score : ",recall_score(y_test, y_pred, pos_label='positive',average='micro'))
# Out:
# Precision Score :  0.5877192982456141
# Recall Score :  0.5877192982456141
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1259: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   % (pos_label, average), UserWarning)

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred=gnb.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,mean_squared_error,r2_score
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print("Training Score: ",gnb.score(X_train,y_train)*100)
print(gnb.score(X_test,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.04      0.08        47
#            1       0.59      0.99      0.74        67
#
#     accuracy                           0.60       114
#    macro avg       0.63      0.51      0.41       114
# weighted avg       0.62      0.60      0.47       114
#
# [[ 2 45]
#  [ 1 66]]
# 0.5964912280701754
# Training Score:  63.29670329670329
# 0.5964912280701754

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#      Actual  Predicted
# 512       0          1
# 457       1          1
# 439       1          1
# 298       1          1
# 37        1          1
# ..      ...        ...
# 213       0          0
# 519       1          1
# 432       0          1
# 516       0          1
# 500       1          1
#
# [114 rows x 2 columns]
